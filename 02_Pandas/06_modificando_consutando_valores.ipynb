# %%
import pandas as pd

#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';', encoding='cp1252')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';', encoding='cp1252')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';', encoding='cp1252')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';', encoding='cp1252')

# Renomear nome da coluna
clientes_df = clientes_df.rename(columns={'ÿID Cliente': 'ID Cliente'})
produtos_df = produtos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'})
lojas_df = lojas_df.rename(columns={'ÿID Loja': 'ID Loja'})

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})

# %%
novo_produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';', encoding='cp1252')
novo_produtos_df = novo_produtos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'})
display(novo_produtos_df.head())
# Out:
#                                    Nome do Produto  \
# 0            Contoso Wireless Laser Mouse E50 Grey
# 1    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 3                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 4                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 1       Contoso  Econômico           6,63             13         879
# ...

# %% [markdown]
# ### Antes de entrar no próximo exemplo, precisamos falar de 2 métodos:
#
#     1. set_index - permite trasformar os valores de uma coluna em índice.
#
#     2. loc - permite pegar uma linha de acordo com o índice dela. Ele dá erro caso não encontre o índice. Isso é interessante principalmente quando o         índice é uma informação relevante ao invés só do número do índice ou quando queremos pegar alguma linha específica do dataframe (ao invés de ir        do início do dataframe até a linha 5, por exemplo). Também podemos usar como loc[índice_linha, índice_coluna] para acessar um valor específico         e modificá-lo.
#
#     3. iloc - enxerga o dataframe como linhas e colunas e consegue pegar o valor com um número de linha e um número de coluna. Repara que ele não             analisa o valor do índice da linha e da coluna, apenas a posição importa.
#         Uso: iloc[num_linha, num_coluna]
#
# - Vendo na prática

# %%
#display(novo_produtos_df)

# %%
#fatiando os indices
novo_produtos_df.loc[1:5]
# Out:
#                                    Nome do Produto  \
# 1    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# 5       Contoso Bluetooth Notebook Mouse E70 Black
#
#                                 Descricao do Produto    Fabricante  \
# 1                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 3                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 4                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 5  Transceiver-free wireless connection to your P...  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 1       Contoso  Econômico           6,63             13         879
# 2       Contoso  Econômico           6,63             13         880
# ...

# %%
#Escolhendo os indices
novo_produtos_df.loc[[0,2,3]]
# Out:
#                                   Nome do Produto  \
# 0           Contoso Wireless Laser Mouse E50 Grey
# 2  Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3  Contoso Optical Wheel OEM PS/2 Mouse E60 White
#
#                                 Descricao do Produto    Fabricante  \
# 0  Advanced 2.4 GHz cordless technology makes fre...  Contoso, Ltd
# 2                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
# 3                     PS/2 mouse, 6 feet mouse cable  Contoso, Ltd
#
#   Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0       Contoso  Econômico          10,69          20,96         873
# 2       Contoso  Econômico           6,63             13         880
# 3       Contoso  Econômico           6,63             13         881
#
#    ID Subcategoria
# 0               22
# 2               22
# 3               22

# %%
#trasnformando coluna 'Nome do Produto' em índice
novo_produtos_df = novo_produtos_df.set_index('Nome do Produto')

# %%
#acessando indice pelo nome
novo_produtos_df.loc[['Contoso Optical Wheel OEM PS/2 Mouse E60 Black']]
# Out:
#                                                           Descricao do Produto  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black  PS/2 mouse, 6 feet mouse cable
#
#                                                   Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black  Contoso, Ltd       Contoso
#
#                                                      Tipo Custo Unitario  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black  Econômico           6,63
#
#                                                Preco Unitario  ID Produto  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black             13         880
#
#                                                 ID Subcategoria
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black               22

# %%
#Acessando valor pelo indice e coluna
novo_produtos_df.loc['Contoso Optical Wheel OEM PS/2 Mouse E60 Black', 'Preco Unitario']
# Out:
# '13'

# %%
novo_produtos_df.iloc[1:5]
# Out:
#                                                            Descricao do Produto  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White   PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver  PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 White   Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver  Contoso, Ltd       Contoso
#
#                                                       Tipo Custo Unitario  \
# Nome do Produto
# ...

# %% [markdown]
# ### Alterar preço do produto ID 873 e ID 879

# %%
#Método 1 - Usando Indice e Coluna
novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = 30

# %%
#Metodo 2 - Usando uma comparação lógica
novo_produtos_df.loc[novo_produtos_df['ID Produto'] == 879, 'Preco Unitario'] = 30

# %%
display(novo_produtos_df.head())
# Out:
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...
